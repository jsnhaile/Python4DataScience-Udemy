# %% [markdown]
# *This workbook is used to conduct EDA on a sample data set pulled from The Intelligent Investor (Chapter 14)*

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('StockPractice.csv')

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital
# 0                         17.6           0.0                        NaN
# 1                         11.7           0.0                        NaN
# 2                         10.2           0.0                        NaN
# 3                          7.9           0.0                       0.39
# 4                          6.7         156.9                       0.04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
# Company                        7 non-null object
# CurrentAssets                  7 non-null float64
# CurrentLiabilities             7 non-null float64
# RationofAssetstoLiabilities    7 non-null float64
# LongTermDebt                   7 non-null float64
# RatioDebttoWorkingCapital      2 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 408.0+ bytes

# %%
#df['CurrentAssets']

# %%
#find the max of the Current Liabilities
df['CurrentLiabilities'].max()
# Out:
# 654.5

# %%
#find the name of the company with the highest current liabilities
df[df['CurrentLiabilities'] == df['CurrentLiabilities'].max()]['Company']
#follow the syntax for [condition][filter]
# Out:
# 4    Qualcomm
# Name: Company, dtype: object

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital
# 0                         17.6           0.0                        NaN
# 1                         11.7           0.0                        NaN
# 2                         10.2           0.0                        NaN
# 3                          7.9           0.0                       0.39
# 4                          6.7         156.9                       0.04
# ...

# %%
#lets fill the NaNs in the DebtoWorking with the mean of the values in the columns
df['RatioDebttoWorkingCapital'].fillna(value = df['RatioDebttoWorkingCapital'].mean(), inplace=True)

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...

# %%
#find the average current liabilities
df['CurrentLiabilities'].mean()
# Out:
# 285.07142857142856

# %%
#find the current assets of Linear Technology
df[df['Company'] == 'Linear Technology']['CurrentAssets']
# Out:
# 1    1736.4
# Name: CurrentAssets, dtype: float64

# %%
#pull data from from 3 to the end of the table, excluding the DebttoWorkingCaptial column
df.iloc[3:,:5]
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt
# 3                          7.9           0.0
# 4                          6.7         156.9
# 5                          6.5           0.0
# 6                          4.3           0.0

# %%
#select the current assets and current liabilities columns for all the companies using iloc
df.iloc[:,:3]
# Out:
#                      Company  CurrentAssets  CurrentLiabilities
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6

# %%
#select the current assets and current liabilities columns for all the companies using column names
df[['Company','CurrentAssets','CurrentLiabilities']]
# Out:
#                      Company  CurrentAssets  CurrentLiabilities
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...

# %%
#list the Current Liabilities in ascending order
df['CurrentLiabilities'].sort_values(ascending=True)
# Out:
# 0     61.9
# 2     69.6
# 1    148.1
# 5    212.5
# 6    381.6
# 3    467.3
# 4    654.5
# Name: CurrentLiabilities, dtype: float64

# %%
df[['Company','CurrentLiabilities']].sort_values(['CurrentLiabilities'], ascending=False)
#the dataframe we want, followed by the parameters that we want to sort by
# Out:
#                      Company  CurrentLiabilities
# 4                   Qualcomm               654.5
# 3             Analog Devices               467.3
# 6                   Novellus               381.6
# 5  Maxim Integrated Products               212.5
# 1          Linear Technology               148.1
# 2                     Qlogic                69.6
# 0              Applied Micro                61.9

# %%
#create a new column that adds the currentassets + the liabilities
df['New'] = df['CurrentAssets'] + df['CurrentLiabilities']

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital  \
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital  \
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...

# %%
#list the Current Assets in descending order
df[['Company','CurrentAssets']].sort_values(['CurrentAssets'], ascending=False)
# Out:
#                      Company  CurrentAssets
# 4                   Qualcomm         4368.5
# 3             Analog Devices         3711.1
# 1          Linear Technology         1736.4
# 6                   Novellus         1633.9
# 5  Maxim Integrated Products         1390.5
# 0              Applied Micro         1091.2
# 2                     Qlogic          713.1

# %%
#list the Current Assets in descending order with the Current Liabilities
df[['Company','CurrentAssets','CurrentLiabilities']].sort_values(['CurrentAssets'], ascending=False)
# Out:
#                      Company  CurrentAssets  CurrentLiabilities
# 4                   Qualcomm         4368.5               654.5
# 3             Analog Devices         3711.1               467.3
# 1          Linear Technology         1736.4               148.1
# 6                   Novellus         1633.9               381.6
# 5  Maxim Integrated Products         1390.5               212.5
# 0              Applied Micro         1091.2                61.9
# 2                     Qlogic          713.1                69.6

# %%
#list companies who have a Current Assets > 1500 and sort those values in ascending order

# %%
df[df['CurrentAssets'] > 1500][['Company','CurrentAssets']].sort_values(by='CurrentAssets',ascending=False)
# Out:
#              Company  CurrentAssets
# 4           Qualcomm         4368.5
# 3     Analog Devices         3711.1
# 1  Linear Technology         1736.4
# 6           Novellus         1633.9

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital  \
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...

# %%
df.drop('New', axis=1, inplace=True)

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...

# %%
#show the name of the comapny with highest long term debt
df[df['LongTermDebt'] == df['LongTermDebt'].max()]['Company']
# Out:
# 4    Qualcomm
# Name: Company, dtype: object

# %%
#find Qualcomm's long term debt using iloc positions
df.iloc[4,4]
# Out:
# 156.90000000000001

# %%
#find Qualcomm's long term debt using condition and filter
df[df['Company'] == 'Qualcomm']['LongTermDebt']
# Out:
# 4    156.9
# Name: LongTermDebt, dtype: float64

# %%
#find current assets of Analog Devices
df[df['Company'] == 'Analog Devices']['CurrentAssets']
# Out:
# 3    3711.1
# Name: CurrentAssets, dtype: float64

# %%
df
# Out:
#                      Company  CurrentAssets  CurrentLiabilities  \
# 0              Applied Micro         1091.2                61.9
# 1          Linear Technology         1736.4               148.1
# 2                     Qlogic          713.1                69.6
# 3             Analog Devices         3711.1               467.3
# 4                   Qualcomm         4368.5               654.5
# 5  Maxim Integrated Products         1390.5               212.5
# 6                   Novellus         1633.9               381.6
#
#    RationofAssetstoLiabilities  LongTermDebt  RatioDebttoWorkingCapital
# 0                         17.6           0.0                      0.215
# 1                         11.7           0.0                      0.215
# 2                         10.2           0.0                      0.215
# 3                          7.9           0.0                      0.390
# 4                          6.7         156.9                      0.040
# ...
